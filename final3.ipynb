# %%
from bs4 import BeautifulSoup     
from selenium import webdriver
import urllib.request
import urllib
import time
import sys
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import os
import random
import requests
query_txt = input('크롤링할 키워드는 무엇입니까?:')
num = input('크롤링 할 건수는 몇개입니까?:')
f_dir = input('파일이 저장될 경로만 쓰시오(예: /Users/jun-mac/final/image/): ')
path = "/Users/jun-mac/py_temp/chromedriver.exec"
driver = webdriver.Chrome(path)
driver.get("https://pixabay.com/ko/")
time.sleep(2)
driver.find_element(By.NAME, 'search').click()
element =driver.find_element(By.NAME,'search')
element.send_keys(query_txt)
#Step 3. 검색 버튼을 눌러 실행합니다
time.sleep(5)
#driver.find_element(By.CLASS_NAME, 'submit--EM').click()
driver.find_element(By.XPATH, '//*[@id="app"]/div[1]/div[1]/div[3]/div[1]/div/form/button').click()
time.sleep(5)


os.chdir(f_dir)
file_no = 0                                
count = 1
img_srcs=[]
full_html = driver.page_source
soup = BeautifulSoup(full_html, 'html.parser')
img_src = soup.find('div','verticalMasonry--RoKfF').find_all('img')
#이미지 정보
for i in img_src :
        temp=i['src']
        img_srcs.append(temp)
        #dload.save(temp, f'image/{count}.jpg') 
        count += 1
        if count==num:
            break

test='/Users/jun-mac/final/image/1.jpg'
for i in range(0,len(img_srcs)) :
        try:
            #temp_f='f_dir'+str(fil
            #urllib.request.urlretrieve(img_srcs[i],str(file_no)+'.jpg')#실행안됨
            #실행됨
            filename=str(file_no)+'.jpg'
            url =img_srcs[i]
            r = requests.get(url)
            with open(f_dir+filename,"wb") as outfile:
                outfile.write(r.content)
            #urllib.request.urlretrieve(img_srcs[i],str(temp_f)+'.jpg')
            file_no += 1
            if file_no==num:
                break
        except:
                #gif제외
                print('jpg가 아님')
                continue
# Out:
# 크롤링할 키워드는 무엇입니까?:디즈니
# 크롤링 할 건수는 몇개입니까?:20
# 파일이 저장될 경로만 쓰시오(예: /Users/jun-mac/final/image/): /Users/jun-mac/final/image/
# /var/folders/51/zbd0hjg97c557zg4v527hz2m0000gn/T/ipykernel_1234/4228685754.py:18: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
# jpg가 아님
